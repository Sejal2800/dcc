# %%
e# %pip install snowflake-connector-python
# %pip install "pandas<2.1"  # Optional: If you face compatibility issues

# %%
# %sh
# wget https://repo1.maven.org/maven2/net/snowflake/snowflake-jdbc/3.13.25/snowflake-jdbc-3.13.25.jar -P /databricks/jars
# wget https://repo1.maven.org/maven2/net/snowflake/spark-snowflake_2.12/2.12.1-spark_3.2/spark-snowflake_2.12-2.12.1-spark_3.2.jar -P /databricks/jars
# %sh
# wget https://repo1.maven.org/maven2/net/snowflake/spark-snowflake_2.12/2.11.1-spark_3.1/spark-snowflake_2.12-2.11.1-spark_3.1.jar -P /databricks/jars

# %%
# %sh
# ls -lh /databricks/jars/ | grep "snowflake"

# %%
from pyspark.sql import SparkSession

# Initialize Spark Session
spark = SparkSession.builder \
    .appName("Databricks-Snowflake") \
    .config("spark.jars", "/databricks/jars/snowflake-jdbc-3.13.25.jar,/databricks/jars/spark-snowflake_2.12-2.11.1-spark_3.1.jar") \
    .getOrCreate()

# Snowflake connection properties
sf_options = {
    "sfURL": "https://SDQFTUJ-EU11435.snowflakecomputing.com",
    "sfWarehouse": "COMPUTE_WH",  # Update with the correct warehouse
    "sfDatabase": "DATAQUALITY",
    "sfSchema": "OUTPUT",
    "user": "ARYAN219",
    "password": "Kanpur@1234567"  # Replace with your actual Snowflake password
}


# Read data from Snowflake

# %%
# notebook_path = dbutils.notebook.entry_point.getDbutils().notebook().getContext().notebookPath().get()
# print(notebook_path)
